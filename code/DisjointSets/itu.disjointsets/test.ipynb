# %%
sum = 0
i = 1
while i < 1000:
    j = 0
    while j < i:
        sum += 1
        j += 1
    i +=1
    print("i =",  i)
    print("j =", j)
    print("sum = ", sum)
    print("------------------------")
print(sum)
# Out:
# i = 2
# j = 1
# sum =  1
# ------------------------
# i = 3
# j = 2
# sum =  3
# ------------------------
# i = 4
# j = 3
# sum =  6
# ------------------------
# i = 5
# j = 4
# sum =  10
# ------------------------
# i = 6
# j = 5
# sum =  15
# ------------------------
# i = 7
# j = 6
# sum =  21
# ------------------------
# i = 8
# j = 7
# sum =  28
# ------------------------
# i = 9
# j = 8
# sum =  36
# ------------------------
# i = 10
# j = 9
# sum =  45
# ------------------------
# i = 11
# j = 10
# sum =  55
# ------------------------
# i = 12
# j = 11
# sum =  66
# ------------------------
# i = 13
# j = 12
# sum =  78
# ------------------------
# i = 14
# j = 13
# sum =  91
# ------------------------
# i = 15
# j = 14
# sum =  105
# ------------------------
# i = 16
# j = 15
# sum =  120
# ------------------------
# i = 17
# j = 16
# sum =  136
# ------------------------
# i = 18
# j = 17
# sum =  153
# ------------------------
# i = 19
# j = 18
# sum =  171
# ...

# %%
sum = 0
i = 1
while i < 1000:
    j = 0
    while j < 1000:
        sum += 1
        j += 1
    i *=2
    
print(sum)
# Out:
# 10000
